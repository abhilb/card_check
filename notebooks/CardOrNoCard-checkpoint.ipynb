# %%
# %load_ext nb_black

# %%
from pathlib import Path
import numpy as np
import PIL
import PIL.Image
import tensorflow as tf

# %%
batch_size = 16
img_height = 270
img_width = 480
IMG_SIZE = (img_height, img_width)
IMG_SHAPE = (img_height, img_width, 3)

# %%
data_dir = Path().absolute().parent / "train1"
data_dir.exists()
test_dir = Path().absolute().parent / "test"
test_dir.exists()
# Out:
# True

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    validation_split=0.1,
    subset="training",
    seed=42,
    image_size=(img_height, img_width),
    batch_size=batch_size,
)
# Out:
# Found 6000 files belonging to 2 classes.
# Using 5400 files for training.

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    validation_split=0.1,
    subset="validation",
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size,
)
# Out:
# Found 6000 files belonging to 2 classes.
# Using 600 files for validation.

# %%
class_names = train_ds.class_names
class_names
# Out:
# ['card', 'nocard']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %%
data_augmentation = tf.keras.Sequential(
    [
        tf.keras.layers.experimental.preprocessing.RandomFlip("horizontal"),
        tf.keras.layers.experimental.preprocessing.RandomRotation(0.2),
    ]
)

# %%
preprocess_input = tf.keras.applications.mobilenet_v2.preprocess_input

# %%
IMG_SHAPE = IMG_SIZE + (3,)
base_model = tf.keras.applications.MobileNetV2(
    input_shape=IMG_SHAPE, include_top=False, weights="imagenet"
)
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.

# %%
image_batch, label_batch = next(iter(train_ds))
feature_batch = base_model(image_batch)
print(feature_batch.shape)
# Out:
# (16, 9, 15, 1280)

# %%
base_model.trainable = False

# %%
global_average_layer = tf.keras.layers.GlobalAveragePooling2D()
feature_batch_average = global_average_layer(feature_batch)
print(feature_batch_average.shape)
# Out:
# (16, 1280)

# %%
prediction_layer = tf.keras.layers.Dense(1)
prediction_batch = prediction_layer(feature_batch_average)
print(prediction_batch.shape)
# Out:
# (16, 1)

# %%
inputs = tf.keras.Input(shape=(160, 160, 3))
x = data_augmentation(inputs)
x = preprocess_input(x)
x = base_model(x, training=False)
x = global_average_layer(x)
x = tf.keras.layers.Dropout(0.2)(x)
outputs = prediction_layer(x)
model = tf.keras.Model(inputs, outputs)
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 270, 480, 3) for input Tensor("input_1:0", shape=(None, 270, 480, 3), dtype=float32), but it was called on an input with incompatible shape (None, 160, 160, 3).

# %%
base_learning_rate = 0.0001
model.compile(
    optimizer=tf.keras.optimizers.Adam(lr=base_learning_rate),
    loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
    metrics=["accuracy"],
)

# %%
val_batches = tf.data.experimental.cardinality(val_ds)
test_dataset = val_ds.take(val_batches // 5)
val_ds = val_ds.skip(val_batches // 5)

# %%
initial_epochs = 15

loss0, accuracy0 = model.evaluate(val_ds)
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 160, 160, 3) for input Tensor("input_2:0", shape=(None, 160, 160, 3), dtype=float32), but it was called on an input with incompatible shape (None, 270, 480, 3).
# WARNING:tensorflow:Model was constructed with shape (None, 160, 160, 3) for input Tensor("input_2:0", shape=(None, 160, 160, 3), dtype=float32), but it was called on an input with incompatible shape (None, 270, 480, 3).
# 31/31 [==============================] - 52s 2s/step - loss: 0.6750 - accuracy: 0.3443

# %%
history = model.fit(train_ds, epochs=initial_epochs, validation_data=val_ds)
# Out:
# Epoch 1/15
# WARNING:tensorflow:Model was constructed with shape (None, 160, 160, 3) for input Tensor("input_2:0", shape=(None, 160, 160, 3), dtype=float32), but it was called on an input with incompatible shape (None, 270, 480, 3).
# WARNING:tensorflow:Model was constructed with shape (None, 160, 160, 3) for input Tensor("input_2:0", shape=(None, 160, 160, 3), dtype=float32), but it was called on an input with incompatible shape (None, 270, 480, 3).
# 338/338 [==============================] - 717s 2s/step - loss: 0.4698 - accuracy: 0.7719 - val_loss: 0.3856 - val_accuracy: 0.8279
# Epoch 2/15
# 338/338 [==============================] - 633s 2s/step - loss: 0.3807 - accuracy: 0.8515 - val_loss: 0.3238 - val_accuracy: 0.8852
# Epoch 3/15
# 338/338 [==============================] - 621s 2s/step - loss: 0.3278 - accuracy: 0.8857 - val_loss: 0.2866 - val_accuracy: 0.9098
# Epoch 4/15
# 338/338 [==============================] - 621s 2s/step - loss: 0.2882 - accuracy: 0.9041 - val_loss: 0.2528 - val_accuracy: 0.9283
# Epoch 5/15
# 338/338 [==============================] - 620s 2s/step - loss: 0.2608 - accuracy: 0.9174 - val_loss: 0.2355 - val_accuracy: 0.9344
# Epoch 6/15
# 338/338 [==============================] - 80536s 238s/step - loss: 0.2427 - accuracy: 0.9246 - val_loss: 0.2147 - val_accuracy: 0.9488
# Epoch 7/15
# 338/338 [==============================] - 1205s 4s/step - loss: 0.2247 - accuracy: 0.9319 - val_loss: 0.2072 - val_accuracy: 0.9467
# Epoch 8/15
# 338/338 [==============================] - 748s 2s/step - loss: 0.2143 - accuracy: 0.9378 - val_loss: 0.1960 - val_accuracy: 0.9488
# Epoch 9/15
# 338/338 [==============================] - 778s 2s/step - loss: 0.2020 - accuracy: 0.9398 - val_loss: 0.1862 - val_accuracy: 0.9549
# Epoch 10/15
# 338/338 [==============================] - 815s 2s/step - loss: 0.1968 - accuracy: 0.9417 - val_loss: 0.1687 - val_accuracy: 0.9570
# Epoch 11/15
# 338/338 [==============================] - 733s 2s/step - loss: 0.1890 - accuracy: 0.9444 - val_loss: 0.1721 - val_accuracy: 0.9570
# Epoch 12/15
#   8/338 [..............................] - ETA: 9:36 - loss: 0.2465 - accuracy: 0.9219

# %%
acc = history.history["accuracy"]
val_acc = history.history["val_accuracy"]

loss = history.history["loss"]
val_loss = history.history["val_loss"]

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label="Training Accuracy")
plt.plot(val_acc, label="Validation Accuracy")
plt.legend(loc="lower right")
plt.ylabel("Accuracy")
plt.ylim([min(plt.ylim()), 1])
plt.title("Training and Validation Accuracy")

plt.subplot(2, 1, 2)
plt.plot(loss, label="Training Loss")
plt.plot(val_loss, label="Validation Loss")
plt.legend(loc="upper right")
plt.ylabel("Cross Entropy")
plt.ylim([0, 1.0])
plt.title("Training and Validation Loss")
plt.xlabel("epoch")
plt.show()

# %%
idx = 1
plt.figure(figsize=(10, 10))
import random

fnames = list(test_dir.rglob("*.jpg"))
indices = list(range(len(fnames)))
random.shuffle(indices)

for fidx in indices[0:10]:
    fname = fnames[fidx]
    plt.subplot(5, 2, idx)
    img = tf.keras.preprocessing.image.load_img(fname, target_size=IMG_SIZE)
    img_arr = tf.keras.preprocessing.image.img_to_array(img)
    img_arr = np.array([img_arr])
    prediction = model.predict(img_arr)
    prediction = tf.nn.sigmoid(prediction)
    title = "NoCard" if prediction >= 0.5 else "Card"
    plt.imshow(img)
    plt.axis("off")
    plt.title(title)
    idx += 1
    if idx > 10:
        break
plt.show()
